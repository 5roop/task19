# %%
# %%bash
# cd /home/rupnik/parlamint/ParlaMint
# git checkout data-HR
# rm Data/ParlaMint-HR/ParlaMint-HR*T*.xml
# cp ../S_3/* Data/ParlaMint-HR
# Out:
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S01.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S02.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S03.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S04.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S05.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S06.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S07.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S08.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S09.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S10.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S11.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S12.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S13.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S14.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S15.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S16.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S17.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S18.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S19.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S20.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S21.xml
# ...

# %%
import os
from pathlib import Path
from utils import fix_component

lang = "HR"
parlamint_dir = Path("/home/rupnik/parlamint/ParlaMint")
os.chdir(str(parlamint_dir))
os.system("pwd")
os.system(f"git checkout data-{lang}")


files = (parlamint_dir / "Data" / f"ParlaMint-{lang}").glob("ParlaMint*")
import re

files = [i for i in files if re.search(pattern=".*ParlaMint-.*T[0-9].*\.xml", string=str(i)) is not None]
for i in files:
    fix_component(i, i)
    # pass
os.system(f"make add-common-content-{lang}; cd Data/ParlaMint-{lang}/; cp add-common-content/* . ; rm -r add-common-content")
os.system("git add *; git commit -m 'Run remark extraction'")
# Out:
# /home/rupnik/parlamint/ParlaMint
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S01.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S02.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S03.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S04.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S05.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S06.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S07.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S08.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S09.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S10.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S11.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S12.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S13.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S14.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S15.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S16.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S17.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S18.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S19.xml
# M	Data/ParlaMint-HR/ParlaMint-HR_T05_S20.xml
# ...

# %%
# %%bash
# cd /home/rupnik/parlamint/ParlaMint
# git checkout data-BA
# rm Data/ParlaMint-BA/ParlaMint-BA*T*.xml
# cp ../BiH/S/* Data/ParlaMint-BA
# Out:
# Your branch is ahead of 'origin/data-BA' by 1 commit.
#   (use "git push" to publish your local commits)
# Switched to branch 'data-BA'

# %%
import os
from pathlib import Path
from utils import fix_component

lang = "BA"

parlamint_dir = Path("/home/rupnik/parlamint/ParlaMint")
os.chdir(str(parlamint_dir))
os.system(f"git checkout data-{lang}")


files = (parlamint_dir / "Data" / f"ParlaMint-{lang}").glob("ParlaMint*")
import re

files = [i for i in files if re.search(pattern=".*ParlaMint-.*T[0-9].*\.xml", string=str(i)) is not None]
print(files)
for i in files:
    fix_component(i, i)
os.system(f"make add-common-content-{lang}; cd Data/ParlaMint-{lang}/; cp add-common-content/* . ; rm -r add-common-content")
os.system("git add *; git commit -m 'Run remark extraction'")
# Out:
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S01.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S02.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S03.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S04.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S05.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S06.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S07.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S08.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S09.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S10.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S11.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S12.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S13.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S14.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S15.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S16.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S17.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S18.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S19.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S20.xml
# M	Data/ParlaMint-BA/ParlaMint-BA_T02S21.xml
# ...

# %%
# %%bash
# cd /home/rupnik/parlamint/ParlaMint
# git checkout data-RS
# rm Data/ParlaMint-RS/ParlaMint-RS*T*.xml
# cp ../SRB/S/* Data/ParlaMint-RS
# Out:
# Your branch is ahead of 'origin/data-RS' by 1 commit.
#   (use "git push" to publish your local commits)
# Switched to branch 'data-RS'

# %%
import os
from pathlib import Path
from utils import fix_component

lang = "RS"

parlamint_dir = Path("/home/rupnik/parlamint/ParlaMint")
os.chdir(str(parlamint_dir))
os.system(f"git checkout data-{lang}")


files = (parlamint_dir / "Data" / f"ParlaMint-{lang}").glob("ParlaMint*")
import re

files = [i for i in files if re.search(pattern=".*ParlaMint-.*T[0-9].*\.xml", string=str(i)) is not None]
for i in files:
    fix_component(i, i)
os.system(f"make add-common-content-{lang}; cd Data/ParlaMint-{lang}/; cp add-common-content/* . ; rm -r add-common-content")
os.system("git add *; git commit -m 'Run remark extraction'")
# Out:
# M	Data/ParlaMint-RS/ParlaMint-RS_T04S1.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T04S2.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T04S3.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T04S4.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T04Sv1.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T04Sv2.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T05S-.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T05S1.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T05S2.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T05S3.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T05S4.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T05S5.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T05S6.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T05S7.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T05S8.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T05Sv1.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T05Sv10.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T05Sv11.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T05Sv12.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T05Sv13.xml
# M	Data/ParlaMint-RS/ParlaMint-RS_T05Sv15.xml
# ...
